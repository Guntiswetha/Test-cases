# %%
# import the required libaries
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# import the fire department of new york city (FNDY) file
df = pd.read_csv("Downloads/14.FDNY.csv",encoding='ISO-8859-1')
df
# Out:
#                                           FacilityName  \
# 0                                         FacilityName
# 1                                   Engine 4/Ladder 15
# 2                                  Engine 10/Ladder 10
# 3                                             Engine 6
# 4    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# ..                                                 ...
# 214                  Engine 162/Ladder 82/Battalion 23
# 215                               Engine 167/Ladder 87
# 216                               Engine 164/Ladder 84
# 217                          Engine 168/EMS Station 23
# 218                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             FacilityAddress        Borough
# 1             42 South Street      Manhattan
# 2          124 Liberty Street      Manhattan
# 3           49 Beekman Street      Manhattan
# 4        100-104 Duane Street      Manhattan
# ...

# %%
# first five records
df.head()
# Out:
#                                         FacilityName        FacilityAddress  \
# 0                                 Engine 4/Ladder 15        42 South Street
# 1                                Engine 10/Ladder 10     124 Liberty Street
# 2                                           Engine 6      49 Beekman Street
# 3  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 4                                           Ladder 8  14 North Moore Street
#
#      Borough
# 0  Manhattan
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
# skip the duplicate header row
df = pd.read_csv("Downloads/14.FDNY.csv",encoding='ISO-8859-1',skiprows=1)
df
# Out:
#                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                  Engine 10/Ladder 10
# 2                                             Engine 6
# 3    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                             Ladder 8
# ..                                                 ...
# 213                  Engine 162/Ladder 82/Battalion 23
# 214                               Engine 167/Ladder 87
# 215                               Engine 164/Ladder 84
# 216                          Engine 168/EMS Station 23
# 217                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             42 South Street      Manhattan
# 1          124 Liberty Street      Manhattan
# 2           49 Beekman Street      Manhattan
# 3        100-104 Duane Street      Manhattan
# 4       14 North Moore Street      Manhattan
# ...

# %%
# the data statistics
df.describe()
# Out:
#         FacilityName  FacilityAddress   Borough
# count            219              219       219
# unique           219              219         6
# top     FacilityName  FacilityAddress  Brooklyn
# freq               1                1        66

# %%
# attribute of the data set
df.columns
# Out:
# Index(['FacilityName', 'FacilityAddress', 'Borough'], dtype='object')

# %%
#index of the data set
df.index
# Out:
# RangeIndex(start=0, stop=219, step=1)

# %%
# count number of records for each attribute
df.count()
# Out:
# FacilityName       219
# FacilityAddress    219
# Borough            219
# dtype: int64

# %%
#the datatypes of all three data types
attributes = ['FacilityName','FacilityAddress','Borough']
data_types=df[attributes].dtypes
print(data_types)
# Out:
# FacilityName       object
# FacilityAddress    object
# Borough            object
# dtype: object

# %%
df["Borough"].describe()
# Out:
# count          219
# unique           6
# top       Brooklyn
# freq            66
# Name: Borough, dtype: object

# %%
 df.iloc [1]
# Out:
# FacilityName       Engine 4/Ladder 15
# FacilityAddress       42 South Street
# Borough                     Manhattan
# Name: 1, dtype: object

# %%
print(df.Borough)
# Out:
# 0            Borough
# 1          Manhattan
# 2          Manhattan
# 3          Manhattan
# 4          Manhattan
#            ...
# 214    Staten Island
# 215    Staten Island
# 216    Staten Island
# 217    Staten Island
# 218    Staten Island
# Name: Borough, Length: 219, dtype: object

# %%
 # veiw the information for each borough
data = df.groupby('Borough')
for Borough, Borough_data in data:
    print(f"info of Borough:{Borough}")
    print(Borough_data[['FacilityName','FacilityAddress']])
    print(Borough_data)
    
    print('\n')
# Out:
# info of Borough:Bronx
#                                      FacilityName             FacilityAddress
# 48               Engine 60/Ladder 17/Battalion 14       341 East 143rd Street
# 49                                       Squad 41       330 East 150th Street
# 50                 Engine 71/Ladder 55/Division 6          720 Melrose Avenue
# 51                            Engine 50/Ladder 19      1155 Washington Avenue
# 52               Engine 92/Ladder 44/Battalion 17          1259 Morris Avenue
# 53                                EMS Station 17            1080 Ogden Avenue
# 54                            Engine 68/Ladder 49          1160 Ogden Avenue
# 55                                 EMS Station 26            1264 Boston Road
# 56               Engine 73/Ladder 42/Battalion 26         655 Prospect Avenue
# 57                Engine 94/Ladder 48/Battalion 3          1226 Seneca Avenue
# 58                                      Engine 42          1781 Monroe Avenue
# ...

# %%
# select the information borough wise
data = df.groupby('Borough')
for Borough, Borough_data in data:
    print(f"info of Borough:{Borough}")
    print(Borough_data)
    
    print('\n')
# Out:
# info of Borough:Bronx
#                                      FacilityName             FacilityAddress  \
# 48               Engine 60/Ladder 17/Battalion 14       341 East 143rd Street
# 49                                       Squad 41       330 East 150th Street
# 50                 Engine 71/Ladder 55/Division 6          720 Melrose Avenue
# 51                            Engine 50/Ladder 19      1155 Washington Avenue
# 52               Engine 92/Ladder 44/Battalion 17          1259 Morris Avenue
# 53                                EMS Station 17            1080 Ogden Avenue
# 54                            Engine 68/Ladder 49          1160 Ogden Avenue
# 55                                 EMS Station 26            1264 Boston Road
# 56               Engine 73/Ladder 42/Battalion 26         655 Prospect Avenue
# 57                Engine 94/Ladder 48/Battalion 3          1226 Seneca Avenue
# 58                                      Engine 42          1781 Monroe Avenue
# ...

# %%
# view information of manhattan data
Manhattan_data = df[df["Borough"]=='Manhattan']
print(Manhattan_data)
# Out:
#                                          FacilityName  \
# 0                                  Engine 4/Ladder 15
# 1                                 Engine 10/Ladder 10
# 2                                            Engine 6
# 3   Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                            Ladder 8
# 5                                   Engine 9/Ladder 6
# 6                     Engine 15/Ladder 18/Battalion 4
# 7                                 Engine 28/Ladder 11
# 8                                            Engine 5
# 9                                           Engine 55
# 10                               Ladder 20/Division 1
# 11                     Engine 24/Ladder 5/Battalion 2
# 12                                 Engine 33/Ladder 9
# 13                               Ladder 3/Battalion 6
# 14                                           Squad 18
# 15                                Engine 34/Ladder 21
# ...
